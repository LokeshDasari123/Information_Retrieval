# %%
import os
import sys
from collections import deque
from string import punctuation

# %%
from nltk.stem import PorterStemmer
from nltk.tokenize import word_tokenize

# %%
class BSBI_indexing:
    def __init__(self, input_dir, block_size, output_dir):
        self.input_dir = input_dir
        self.block_size = block_size
        self.output_dir = output_dir
        self.number_of_documents = 0
        self.docId_to_doc_map = {}
        self.current_block = 0
        self.total_documents_size = 0
        self.current_docId = 0
        self.current_file = 0
        self.punctuation = punctuation
        self.term_to_docIds_map = {}
        self.term_to_docIds_sorted = []
        self.docId_to_terms = None
        self.current_termId = 0
        self.current_block_size = 0
        self.end_of_files = False
        self.porter = PorterStemmer()
        self.number_of_merges = 0

    def making_index(self):
        self.total_documents_size = 0

        print("constructing doc-docID map, please wait")
        # Construct a doc to docId mapping and find total doc size
        doc_index = 0
        for dir_path, dir_names, file_names in os.walk(self.input_dir):
            file_names.sort()
            for file_name in file_names:
                self.docId_to_doc_map[doc_index] = file_name
                file_path = os.path.join(dir_path, file_name)

                # making sure file path points to file, not a link
                if not os.path.islink(file_path):
                    file_size = os.path.getsize(file_path)

                    # if file exceeds the block size limit
                    if file_size >= self.block_size:
                        print("Program failed! {} size exceeds block size limit.".format(
                            self.docId_to_doc_map[doc_index]
                        ))
                        print("file size {} Kb > block size {} Kb".format(
                            file_size / 1024,
                            self.block_size / 1024
                        ))
                        sys.exit(1)
                    self.total_documents_size += file_size
                doc_index += 1

        self.number_of_documents = len(self.docId_to_doc_map)

        # ready output directory
        if not os.path.exists(self.output_dir):
            os.mkdir(self.output_dir)
        else:
            if os.path.isdir(self.output_dir):
                for dir_path, dir_names, file_names in os.walk(self.output_dir):
                    for file_name in file_names:
                        os.remove(os.path.join(dir_path, file_name))
            else:
                os.remove(self.output_dir)
                os.mkdir(self.output_dir)

        # Make Index
        while True:
            if self.current_docId < self.number_of_documents:
                print("Processing Document #{}, please wait. File: {}, Current Block {}"
                      .format(self.current_docId, self.docId_to_doc_map[self.current_docId], self.current_block))
            self.parse_next_document()
            self.invert_document()

            size = sys.getsizeof(self.term_to_docIds_map)
            current_block_size = self.current_block_size + size
            if current_block_size >= self.block_size or self.end_of_files:
                # now it's time to sort term-doc by terms and write it to the disk
                terms = list(self.term_to_docIds_map.keys())
                terms.sort()
                self.term_to_docIds_sorted = []
                for term in terms:
                    self.term_to_docIds_sorted.append((term, self.term_to_docIds_map[term]))
                    del self.term_to_docIds_map[term]
                self.term_to_docIds_map = sorted(self.term_to_docIds_map.items())
                self.write_block()
                self.current_block += 1
                self.term_to_docIds_map = {}
                self.current_block_size = 0
                if self.end_of_files:
                    break

        print("merging state initiated, Please wait")
        self.merge_blocks()
        print("All done!")

    def parse_next_document(self):
        self.docId_to_terms = None

        # receive next doc and it's size
        if self.current_docId > self.number_of_documents - 1:
            self.end_of_files = True
            return
        current_document_path = os.path.join(self.input_dir, self.docId_to_doc_map[self.current_docId])
        self.current_file = open(current_document_path, 'rt', encoding='utf-8')
        current_file_size = os.path.getsize(current_document_path)

        # parse document & make docId to terms List
        if current_file_size <= self.block_size:
            self.docId_to_terms = [self.current_docId, self.current_file.read()]
            self.current_file.close()
            self.current_docId += 1
        else:
            # overflowed the block
            print("Error! {} size exceeds block size limit.".format(
                self.docId_to_doc_map[self.current_docId]
            ))
            print("file size vs block size: {} Kb > {} Kb".format(
                current_file_size / 1024,
                self.block_size / 1024
            ))
            self.end_of_files = True

        # extract tokens form a doc and process them into terms
        self.docId_to_terms[1] = word_tokenize(self.docId_to_terms[1])
        self.preprocess_terms(self.docId_to_terms[1])

    def preprocess_terms(self, terms):
        size_of_terms = len(terms)
        for i in range(0, size_of_terms):
            # Removing Punctuation
            terms[i] = "".join([char for char in terms[i] if char not in punctuation])
            # Lowering all terms
            terms[i] = terms[i].lower()
            # stemming terms
            terms[i] = self.porter.stem(terms[i])

    def invert_document(self):
        if self.end_of_files:
            return
        # store terms as term-document postings
        index = 0
        number_of_new_terms = 0
        document_id = self.docId_to_terms[0]
        terms = self.docId_to_terms[1]
        while index < len(terms):
            term = terms[index]
            if term not in self.term_to_docIds_map:
                number_of_new_terms += 1
                size = sys.getsizeof(term)
                inc = size % 8
                if inc != 0:
                    size += 8 - inc
                self.term_to_docIds_map[term] = []
                self.current_block_size += size
            self.term_to_docIds_map[term].append(document_id)
            index += 1

        size = sys.getsizeof(document_id)
        self.current_block_size += size
        self.current_block_size += number_of_new_terms * 56
        self.current_block_size += number_of_new_terms * size
        self.current_block_size += 8 * index

        del self.docId_to_terms, terms

    def write_block(self):
        with open("{}/block{}.txt".format(self.output_dir, self.current_block), 'wt', encoding='utf-8') as file:
            for term, documents in self.term_to_docIds_sorted:
                for docId in documents:
                    file.write('{} {}\n'.format(term, docId))
        del self.term_to_docIds_map, file

    def merge_blocks(self):
        block_queue = deque()
        block_id = 0
        for dirpath, dirnames, filenames in os.walk(self.output_dir):
            for file in filenames:
                file_path = os.path.join(dirpath, file)
                block_queue.append(file_path)

        del filenames, file, dirpath

        while len(block_queue) > 1:
            file_path_a = block_queue.popleft()
            file_path_b = block_queue.popleft()
            print("merge round #{}".format(self.number_of_merges + 1))
            self.number_of_merges += 1

            merged_path = os.path.join(self.output_dir, 'merged{}.txt'.format(block_id))
            file_a = open(file_path_a, 'rt', encoding='utf-8')
            file_b = open(file_path_b, 'rt', encoding='utf-8')
            term_to_doc_a = file_a.readline()
            term_to_doc_b = file_b.readline()
            if term_to_doc_a == '' or term_to_doc_b == '':
                # file is empty
                file_a.close()
                file_b.close()
                if term_to_doc_a == '' and term_to_doc_b == '':
                    block_id += 2
                    continue
                elif term_to_doc_a == '':
                    os.rename(file_path_b, merged_path)
                elif term_to_doc_b == '':
                    os.rename(file_path_a, merged_path)
                block_queue.append(merged_path)
                block_id += 1
                continue
            merged_file = open(merged_path, 'wt', encoding='utf-8')
            term_doc_a = term_to_doc_a[:-1].split(' ')
            term_doc_b = term_to_doc_b[:-1].split(' ')

            # read line by line from files a , b and  writing on merge file until one of them  reaches end of file
            while True:
                if term_doc_a[0] < term_doc_b[0] or (
                        term_doc_a[0] == term_doc_b[0] and int(term_doc_a[1]) < int(term_doc_b[1])):
                    min_term_doc = term_doc_a
                    file_pointer = file_a
                else:
                    min_term_doc = term_doc_b
                    file_pointer = file_b
                merged_file.write(min_term_doc[0] + ' ' + min_term_doc[1] + '\n')

                if file_pointer == file_a:  # if min was from a
                    term_doc_a = file_a.readline()
                    if term_doc_a == '':
                        break  # file ended
                    term_doc_a = term_doc_a[:-1].split(' ')
                else:  # if min was from b
                    term_doc_b = file_b.readline()
                    if term_doc_b == '':
                        break  # file ended
                    term_doc_b = term_doc_b[:-1].split(' ')

                # check if a is reached the end write b till the end of it in merge file vise versa
            if term_doc_a == '':
                file_pointer = file_b
                file_a.close()
            else:
                file_pointer = file_a
                file_b.close()
            min_term_doc = file_pointer.readline()
            while min_term_doc != '':
                # write till end of selected file
                min_term_doc = min_term_doc[:-1].split(' ')
                merged_file.write(min_term_doc[0] + ' ' + min_term_doc[1] + '\n')
                min_term_doc = file_pointer.readline()
            file_pointer.close()
            merged_file.close()
            block_queue.append(merged_path)
            block_id += 1

        # convert one last merged file doc_ids into doc file name
        merged_file = open(block_queue.pop(), 'rt', encoding='utf-8')
        output_file = open(os.path.join(self.output_dir, 'output.txt'), 'wt', encoding='utf-8')
        term_doc = merged_file.readline()
        while term_doc != '':
            term_doc = term_doc[:-1].split(' ')
            output_file.write(term_doc[0] + ' ' + self.docId_to_doc_map[int(term_doc[1])] + '\n')
            term_doc = merged_file.readline()
        merged_file.close()
        output_file.close()

    def clear_output_directory(self):
        for dirpath, dirnames, filenames in os.walk(self.output_dir):
            for file in filenames:
                if not file == 'output.txt':
                    os.remove(os.path.join(dirpath, file))

# %%
input_directory = '/content/drive/MyDrive/CSE 419/Lab Assign-4/1000_documents'
output_directory = '/content/drive/MyDrive/CSE 419/Lab Assign-4/output_dir'

# initialize block size with 1MB
initial_block_size = 1 * 1024 * 1024

# %%
def calculate_total_file_size_in_bytes(input_directory):
    total_size = 0
    for dir_path, _, file_names in os.walk(input_directory):
        for file_name in file_names:
            file_path = os.path.join(dir_path, file_name)
            total_size += os.path.getsize(file_path)
    return total_size

# %%
total_file_size_in_bytes = calculate_total_file_size_in_bytes(input_directory)
print("Total size of all files: {} bytes".format(total_file_size_in_bytes))
# Out:
# Total size of all files: 2581222 bytes

# %%
import time
import matplotlib.pyplot as plt

# %%
def run_experiment(input_directory, block_size, output_directory):
    indexer = BSBI_indexing(input_directory, block_size, output_directory)
    start_time = time.time()
    indexer.making_index()
    end_time = time.time()
    return end_time - start_time

# %%
block_sizes = []
execution_times = []

block_size = initial_block_size

# %%
while block_size <= 2 * total_file_size_in_bytes:
    print(f"Running experiment with block size: {block_size} bytes")
    time_taken = run_experiment(input_directory, block_size, output_directory)

    block_sizes.append(block_size)
    execution_times.append(time_taken)

    print(f"Time taken with block size {block_size} bytes: {time_taken:.2f} seconds")

    block_size *= 2
# Out:
# Running experiment with block size: 1048576 bytes
# constructing doc-docID map, please wait
# Processing Document #0, please wait. File: business_1.txt, Current Block 0
# Processing Document #1, please wait. File: business_10.txt, Current Block 0
# Processing Document #2, please wait. File: business_100.txt, Current Block 0
# Processing Document #3, please wait. File: business_11.txt, Current Block 0
# Processing Document #4, please wait. File: business_12.txt, Current Block 0
# Processing Document #5, please wait. File: business_13.txt, Current Block 0
# Processing Document #6, please wait. File: business_14.txt, Current Block 0
# Processing Document #7, please wait. File: business_15.txt, Current Block 0
# Processing Document #8, please wait. File: business_16.txt, Current Block 0
# Processing Document #9, please wait. File: business_17.txt, Current Block 0
# Processing Document #10, please wait. File: business_18.txt, Current Block 0
# Processing Document #11, please wait. File: business_19.txt, Current Block 0
# Processing Document #12, please wait. File: business_2.txt, Current Block 0
# Processing Document #13, please wait. File: business_20.txt, Current Block 0
# Processing Document #14, please wait. File: business_21.txt, Current Block 0
# Processing Document #15, please wait. File: business_22.txt, Current Block 0
# Processing Document #16, please wait. File: business_23.txt, Current Block 0
# Processing Document #17, please wait. File: business_24.txt, Current Block 0
# Processing Document #18, please wait. File: business_25.txt, Current Block 0
# Processing Document #19, please wait. File: business_26.txt, Current Block 0
# Processing Document #20, please wait. File: business_27.txt, Current Block 0
# Processing Document #21, please wait. File: business_28.txt, Current Block 0
# Processing Document #22, please wait. File: business_29.txt, Current Block 0
# Processing Document #23, please wait. File: business_3.txt, Current Block 0
# Processing Document #24, please wait. File: business_30.txt, Current Block 0
# Processing Document #25, please wait. File: business_31.txt, Current Block 0
# Processing Document #26, please wait. File: business_32.txt, Current Block 0
# Processing Document #27, please wait. File: business_33.txt, Current Block 0
# Processing Document #28, please wait. File: business_34.txt, Current Block 0
# Processing Document #29, please wait. File: business_35.txt, Current Block 0
# Processing Document #30, please wait. File: business_36.txt, Current Block 0
# Processing Document #31, please wait. File: business_37.txt, Current Block 0
# Processing Document #32, please wait. File: business_38.txt, Current Block 0
# Processing Document #33, please wait. File: business_39.txt, Current Block 0
# Processing Document #34, please wait. File: business_4.txt, Current Block 0
# Processing Document #35, please wait. File: business_40.txt, Current Block 0
# Processing Document #36, please wait. File: business_41.txt, Current Block 0
# Processing Document #37, please wait. File: business_42.txt, Current Block 0
# Processing Document #38, please wait. File: business_43.txt, Current Block 0
# Processing Document #39, please wait. File: business_44.txt, Current Block 0
# Processing Document #40, please wait. File: business_45.txt, Current Block 0
# Processing Document #41, please wait. File: business_46.txt, Current Block 0
# Processing Document #42, please wait. File: business_47.txt, Current Block 0
# Processing Document #43, please wait. File: business_48.txt, Current Block 0
# Processing Document #44, please wait. File: business_49.txt, Current Block 0
# Processing Document #45, please wait. File: business_5.txt, Current Block 0
# Processing Document #46, please wait. File: business_50.txt, Current Block 0
# Processing Document #47, please wait. File: business_51.txt, Current Block 0
# Processing Document #48, please wait. File: business_52.txt, Current Block 0
# Processing Document #49, please wait. File: business_53.txt, Current Block 0
# Processing Document #50, please wait. File: business_54.txt, Current Block 0
# Processing Document #51, please wait. File: business_55.txt, Current Block 0
# Processing Document #52, please wait. File: business_56.txt, Current Block 0
# Processing Document #53, please wait. File: business_57.txt, Current Block 0
# Processing Document #54, please wait. File: business_58.txt, Current Block 0
# Processing Document #55, please wait. File: business_59.txt, Current Block 0
# Processing Document #56, please wait. File: business_6.txt, Current Block 0
# Processing Document #57, please wait. File: business_60.txt, Current Block 0
# Processing Document #58, please wait. File: business_61.txt, Current Block 0
# Processing Document #59, please wait. File: business_62.txt, Current Block 0
# Processing Document #60, please wait. File: business_63.txt, Current Block 0
# Processing Document #61, please wait. File: business_64.txt, Current Block 0
# Processing Document #62, please wait. File: business_65.txt, Current Block 0
# Processing Document #63, please wait. File: business_66.txt, Current Block 0
# Processing Document #64, please wait. File: business_67.txt, Current Block 0
# Processing Document #65, please wait. File: business_68.txt, Current Block 0
# Processing Document #66, please wait. File: business_69.txt, Current Block 0
# Processing Document #67, please wait. File: business_7.txt, Current Block 0
# Processing Document #68, please wait. File: business_70.txt, Current Block 0
# Processing Document #69, please wait. File: business_71.txt, Current Block 0
# Processing Document #70, please wait. File: business_72.txt, Current Block 0
# Processing Document #71, please wait. File: business_73.txt, Current Block 0
# Processing Document #72, please wait. File: business_74.txt, Current Block 0
# Processing Document #73, please wait. File: business_75.txt, Current Block 0
# Processing Document #74, please wait. File: business_76.txt, Current Block 0
# Processing Document #75, please wait. File: business_77.txt, Current Block 0
# Processing Document #76, please wait. File: business_78.txt, Current Block 0
# Processing Document #77, please wait. File: business_79.txt, Current Block 0
# Processing Document #78, please wait. File: business_8.txt, Current Block 0
# Processing Document #79, please wait. File: business_80.txt, Current Block 0
# Processing Document #80, please wait. File: business_81.txt, Current Block 0
# Processing Document #81, please wait. File: business_82.txt, Current Block 0
# Processing Document #82, please wait. File: business_83.txt, Current Block 0
# Processing Document #83, please wait. File: business_84.txt, Current Block 0
# Processing Document #84, please wait. File: business_85.txt, Current Block 0
# Processing Document #85, please wait. File: business_86.txt, Current Block 0
# Processing Document #86, please wait. File: business_87.txt, Current Block 0
# Processing Document #87, please wait. File: business_88.txt, Current Block 0
# Processing Document #88, please wait. File: business_89.txt, Current Block 0
# Processing Document #89, please wait. File: business_9.txt, Current Block 0
# Processing Document #90, please wait. File: business_90.txt, Current Block 0
# Processing Document #91, please wait. File: business_91.txt, Current Block 0
# Processing Document #92, please wait. File: business_92.txt, Current Block 0
# Processing Document #93, please wait. File: business_93.txt, Current Block 0
# Processing Document #94, please wait. File: business_94.txt, Current Block 0
# Processing Document #95, please wait. File: business_95.txt, Current Block 0
# Processing Document #96, please wait. File: business_96.txt, Current Block 0
# Processing Document #97, please wait. File: business_97.txt, Current Block 0
# Processing Document #98, please wait. File: business_98.txt, Current Block 0
# Processing Document #99, please wait. File: business_99.txt, Current Block 0
# Processing Document #100, please wait. File: entertainment_1.txt, Current Block 0
# Processing Document #101, please wait. File: entertainment_10.txt, Current Block 0
# Processing Document #102, please wait. File: entertainment_100.txt, Current Block 1
# Processing Document #103, please wait. File: entertainment_11.txt, Current Block 1
# Processing Document #104, please wait. File: entertainment_12.txt, Current Block 1
# Processing Document #105, please wait. File: entertainment_13.txt, Current Block 1
# Processing Document #106, please wait. File: entertainment_14.txt, Current Block 1
# Processing Document #107, please wait. File: entertainment_15.txt, Current Block 1
# Processing Document #108, please wait. File: entertainment_16.txt, Current Block 1
# Processing Document #109, please wait. File: entertainment_17.txt, Current Block 1
# Processing Document #110, please wait. File: entertainment_18.txt, Current Block 1
# Processing Document #111, please wait. File: entertainment_19.txt, Current Block 1
# Processing Document #418, please wait. File: historical_25.txt, Current Block 4
# Processing Document #419, please wait. File: historical_26.txt, Current Block 4
# Processing Document #420, please wait. File: historical_27.txt, Current Block 4
# Processing Document #421, please wait. File: historical_28.txt, Current Block 4
# Processing Document #422, please wait. File: historical_29.txt, Current Block 4
# Processing Document #423, please wait. File: historical_3.txt, Current Block 4
# Processing Document #424, please wait. File: historical_30.txt, Current Block 4
# Processing Document #425, please wait. File: historical_31.txt, Current Block 4
# Processing Document #426, please wait. File: historical_32.txt, Current Block 4
# Processing Document #427, please wait. File: historical_33.txt, Current Block 4
# Processing Document #428, please wait. File: historical_34.txt, Current Block 4
# Processing Document #429, please wait. File: historical_35.txt, Current Block 4
# Processing Document #430, please wait. File: historical_36.txt, Current Block 4
# Processing Document #431, please wait. File: historical_37.txt, Current Block 4
# Processing Document #432, please wait. File: historical_38.txt, Current Block 4
# Processing Document #433, please wait. File: historical_39.txt, Current Block 4
# Processing Document #434, please wait. File: historical_4.txt, Current Block 4
# Processing Document #435, please wait. File: historical_40.txt, Current Block 4
# Processing Document #436, please wait. File: historical_41.txt, Current Block 4
# Processing Document #437, please wait. File: historical_42.txt, Current Block 4
# Processing Document #438, please wait. File: historical_43.txt, Current Block 4
# Processing Document #439, please wait. File: historical_44.txt, Current Block 4
# Processing Document #440, please wait. File: historical_45.txt, Current Block 4
# Processing Document #441, please wait. File: historical_46.txt, Current Block 4
# Processing Document #442, please wait. File: historical_47.txt, Current Block 4
# Processing Document #443, please wait. File: historical_48.txt, Current Block 4
# Processing Document #444, please wait. File: historical_49.txt, Current Block 4
# Processing Document #445, please wait. File: historical_5.txt, Current Block 4
# Processing Document #446, please wait. File: historical_50.txt, Current Block 4
# Processing Document #447, please wait. File: historical_51.txt, Current Block 4
# Processing Document #448, please wait. File: historical_52.txt, Current Block 4
# Processing Document #449, please wait. File: historical_53.txt, Current Block 4
# Processing Document #450, please wait. File: historical_54.txt, Current Block 5
# Processing Document #451, please wait. File: historical_55.txt, Current Block 5
# Processing Document #452, please wait. File: historical_56.txt, Current Block 5
# Processing Document #453, please wait. File: historical_57.txt, Current Block 5
# Processing Document #454, please wait. File: historical_58.txt, Current Block 5
# Processing Document #455, please wait. File: historical_59.txt, Current Block 5
# Processing Document #456, please wait. File: historical_6.txt, Current Block 5
# Processing Document #457, please wait. File: historical_60.txt, Current Block 5
# Processing Document #458, please wait. File: historical_61.txt, Current Block 5
# Processing Document #459, please wait. File: historical_62.txt, Current Block 5
# Processing Document #460, please wait. File: historical_63.txt, Current Block 5
# Processing Document #461, please wait. File: historical_64.txt, Current Block 5
# Processing Document #462, please wait. File: historical_65.txt, Current Block 5
# Processing Document #463, please wait. File: historical_66.txt, Current Block 5
# Processing Document #464, please wait. File: historical_67.txt, Current Block 5
# Processing Document #465, please wait. File: historical_68.txt, Current Block 5
# Processing Document #466, please wait. File: historical_69.txt, Current Block 5
# Processing Document #467, please wait. File: historical_7.txt, Current Block 5
# Processing Document #468, please wait. File: historical_70.txt, Current Block 5
# Processing Document #469, please wait. File: historical_71.txt, Current Block 5
# Processing Document #914, please wait. File: technologie_21.txt, Current Block 2
# Processing Document #915, please wait. File: technologie_22.txt, Current Block 2
# Processing Document #916, please wait. File: technologie_23.txt, Current Block 2
# Processing Document #917, please wait. File: technologie_24.txt, Current Block 2
# Processing Document #918, please wait. File: technologie_25.txt, Current Block 2
# Processing Document #919, please wait. File: technologie_26.txt, Current Block 2
# Processing Document #920, please wait. File: technologie_27.txt, Current Block 2
# Processing Document #921, please wait. File: technologie_28.txt, Current Block 2
# Processing Document #922, please wait. File: technologie_29.txt, Current Block 2
# Processing Document #923, please wait. File: technologie_3.txt, Current Block 2
# Processing Document #924, please wait. File: technologie_30.txt, Current Block 2
# Processing Document #925, please wait. File: technologie_31.txt, Current Block 2
# Processing Document #926, please wait. File: technologie_32.txt, Current Block 2
# Processing Document #927, please wait. File: technologie_33.txt, Current Block 2
# Processing Document #928, please wait. File: technologie_34.txt, Current Block 2
# Processing Document #929, please wait. File: technologie_35.txt, Current Block 2
# Processing Document #930, please wait. File: technologie_36.txt, Current Block 2
# Processing Document #931, please wait. File: technologie_37.txt, Current Block 2
# Processing Document #932, please wait. File: technologie_38.txt, Current Block 2
# Processing Document #933, please wait. File: technologie_39.txt, Current Block 2
# Processing Document #934, please wait. File: technologie_4.txt, Current Block 2
# Processing Document #935, please wait. File: technologie_40.txt, Current Block 2
# Processing Document #936, please wait. File: technologie_41.txt, Current Block 2
# Processing Document #937, please wait. File: technologie_42.txt, Current Block 2
# Processing Document #938, please wait. File: technologie_43.txt, Current Block 2
# Processing Document #939, please wait. File: technologie_44.txt, Current Block 2
# Processing Document #940, please wait. File: technologie_45.txt, Current Block 2
# Processing Document #941, please wait. File: technologie_46.txt, Current Block 2
# Processing Document #942, please wait. File: technologie_47.txt, Current Block 2
# Processing Document #943, please wait. File: technologie_48.txt, Current Block 2
# Processing Document #944, please wait. File: technologie_49.txt, Current Block 2
# Processing Document #945, please wait. File: technologie_5.txt, Current Block 2
# Processing Document #946, please wait. File: technologie_50.txt, Current Block 2
# Processing Document #947, please wait. File: technologie_51.txt, Current Block 2
# Processing Document #948, please wait. File: technologie_52.txt, Current Block 2
# Processing Document #949, please wait. File: technologie_53.txt, Current Block 2
# Processing Document #950, please wait. File: technologie_54.txt, Current Block 2
# Processing Document #951, please wait. File: technologie_55.txt, Current Block 2
# Processing Document #952, please wait. File: technologie_56.txt, Current Block 2
# Processing Document #953, please wait. File: technologie_57.txt, Current Block 2
# Processing Document #954, please wait. File: technologie_58.txt, Current Block 2
# Processing Document #955, please wait. File: technologie_59.txt, Current Block 2
# Processing Document #956, please wait. File: technologie_6.txt, Current Block 2
# Processing Document #957, please wait. File: technologie_60.txt, Current Block 2
# Processing Document #958, please wait. File: technologie_61.txt, Current Block 2
# Processing Document #959, please wait. File: technologie_62.txt, Current Block 2
# Processing Document #960, please wait. File: technologie_63.txt, Current Block 2
# Processing Document #961, please wait. File: technologie_64.txt, Current Block 2
# Processing Document #962, please wait. File: technologie_65.txt, Current Block 2
# Processing Document #963, please wait. File: technologie_66.txt, Current Block 2
# Processing Document #964, please wait. File: technologie_67.txt, Current Block 2
# Processing Document #965, please wait. File: technologie_68.txt, Current Block 2
# Processing Document #966, please wait. File: technologie_69.txt, Current Block 2
# Processing Document #967, please wait. File: technologie_7.txt, Current Block 2
# Processing Document #968, please wait. File: technologie_70.txt, Current Block 2
# Processing Document #969, please wait. File: technologie_71.txt, Current Block 2
# Processing Document #970, please wait. File: technologie_72.txt, Current Block 2
# Processing Document #971, please wait. File: technologie_73.txt, Current Block 2
# Processing Document #972, please wait. File: technologie_74.txt, Current Block 2
# Processing Document #973, please wait. File: technologie_75.txt, Current Block 2
# Processing Document #974, please wait. File: technologie_76.txt, Current Block 2
# Processing Document #975, please wait. File: technologie_77.txt, Current Block 2
# Processing Document #976, please wait. File: technologie_78.txt, Current Block 2
# Processing Document #977, please wait. File: technologie_79.txt, Current Block 2
# Processing Document #978, please wait. File: technologie_8.txt, Current Block 2
# Processing Document #979, please wait. File: technologie_80.txt, Current Block 2
# Processing Document #980, please wait. File: technologie_81.txt, Current Block 2
# Processing Document #981, please wait. File: technologie_82.txt, Current Block 2
# Processing Document #982, please wait. File: technologie_83.txt, Current Block 2
# Processing Document #983, please wait. File: technologie_84.txt, Current Block 2
# Processing Document #984, please wait. File: technologie_85.txt, Current Block 2
# Processing Document #985, please wait. File: technologie_86.txt, Current Block 2
# Processing Document #986, please wait. File: technologie_87.txt, Current Block 2
# Processing Document #987, please wait. File: technologie_88.txt, Current Block 2
# Processing Document #988, please wait. File: technologie_89.txt, Current Block 2
# Processing Document #989, please wait. File: technologie_9.txt, Current Block 2
# Processing Document #990, please wait. File: technologie_90.txt, Current Block 2
# Processing Document #991, please wait. File: technologie_91.txt, Current Block 2
# Processing Document #992, please wait. File: technologie_92.txt, Current Block 2
# Processing Document #993, please wait. File: technologie_93.txt, Current Block 2
# Processing Document #994, please wait. File: technologie_94.txt, Current Block 2
# Processing Document #995, please wait. File: technologie_95.txt, Current Block 2
# Processing Document #996, please wait. File: technologie_96.txt, Current Block 2
# Processing Document #997, please wait. File: technologie_97.txt, Current Block 2
# Processing Document #998, please wait. File: technologie_98.txt, Current Block 2
# Processing Document #999, please wait. File: technologie_99.txt, Current Block 2
# merging state initiated, Please wait
# merge round #1
# merge round #2
# All done!
# Time taken with block size 4194304 bytes: 19.79 seconds

# %%
# Logarithmic scale
plt.figure(figsize=(10, 6))
plt.plot(block_sizes, execution_times, marker='o')
plt.xscale('log')
plt.xlabel('Block Size (Bytes)')
plt.ylabel('Time Taken (Seconds)')
plt.title('Block Size vs Time Taken (Roll No. AP21110011352)')
plt.grid(True)
plt.show()

# %%
plt.figure(figsize=(10, 6))
plt.plot(block_sizes, execution_times, marker='o')
plt.xlabel('Block Size (Bytes)')
plt.ylabel('Time Taken (Seconds)')
plt.title('Block Size vs Time Taken (Roll No. AP21110011352)')
plt.grid(True)
plt.show()

# %%
for b_size, time_taken in zip(block_sizes, execution_times):
    print(f"Block Size: {b_size} bytes - Time Taken: {time_taken:.2f} seconds")
# Out:
# Block Size: 1048576 bytes - Time Taken: 29.70 seconds
# Block Size: 2097152 bytes - Time Taken: 22.32 seconds
# Block Size: 4194304 bytes - Time Taken: 19.79 seconds
