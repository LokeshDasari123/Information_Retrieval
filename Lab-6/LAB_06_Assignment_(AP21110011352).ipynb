# %% [markdown]
# <h1> <center> Assignment 06: Dynamic Indexing Algorithm </center>  </h1>

# %% [markdown]
# #### Following Python code is generated from one of the GenAI tool.

# %%
import os
from collections import defaultdict

class IndexSegment:
    def __init__(self):
        self.index = defaultdict(list)

    def add_document(self, doc_id, content):
        terms = content.lower().split()
        for position, term in enumerate(terms):
            self.index[term].append((doc_id, position))

    def merge(self, other):
        for term, postings in other.index.items():
            self.index[term].extend(postings)
        return self


class DynamicIndex:
    def __init__(self, merge_threshold=2, buffer_size=5):
        self.segments = []
        self.merge_threshold = merge_threshold
        self.buffer_size = buffer_size
        self.buffer = IndexSegment()
        self.buffer_count = 0

    def add_document(self, doc_id, content):
        self.buffer.add_document(doc_id, content)
        self.buffer_count += 1

        if self.buffer_count >= self.buffer_size:
            self._flush_buffer()

    def _flush_buffer(self):
        if self.buffer_count > 0:
            self.segments.append(self.buffer)
            self.buffer = IndexSegment()
            self.buffer_count = 0
            self._merge_segments()

    def _merge_segments(self):
        i = 0
        while i < len(self.segments) - 1:
            if len(self.segments) - i >= self.merge_threshold:
                merged = self.segments[i]
                for j in range(1, self.merge_threshold):
                    merged = merged.merge(self.segments[i + j])
                self.segments[i] = merged
                del self.segments[i + 1 : i + self.merge_threshold]
            i += 1

    def search(self, query):
        results = []
        for segment in self.segments:
            results.extend(segment.index.get(query.lower(), []))

        results.extend(self.buffer.index.get(query.lower(), []))
        return results

    def update_document(self, doc_id, new_content):

        for segment in self.segments:
            segment.index = defaultdict(list, {term: [(d, p) for d, p in postings if d != doc_id]
                                               for term, postings in segment.index.items()})
        self.buffer.index = defaultdict(list, {term: [(d, p) for d, p in postings if d != doc_id]
                                               for term, postings in self.buffer.index.items()})
        self.add_document(doc_id, new_content)

# %% [markdown]
# ### 1. Go through the code. Write the Driver Code to execute the Dynamic Indexing.
# [Try with dummy Data without reading files from secondary storage]
#
# ### 2. Write Explaination for each Method in both the classes.
#
# ### 3. Explain merge_threshold and buffer_size in the context on this code.
#
# ### 4. Next, execute the code on the 1000 documents dataset. https://www.kaggle.com/datasets/jensenbaxter/10dataset-text-document-classification
#
# ### 5. Write the driver code to execute the search document functionality. [Execute 2-3 examples]

# %% [markdown]
# ### **1.** **Driver** Code

# %%
if __name__ == "__main__":
  index = DynamicIndex(merge_threshold=2, buffer_size=5)
  documents = {
    1: "Information retrieval is the process of obtaining information system resources that are relevant to an information need from a collection of those resources.",
    2: "Python is a versatile programming language used for web development, data analysis, artificial intelligence, and more.",
    3: "In information retrieval, indexing is crucial for efficient search and retrieval of data.",
    4: "Python libraries such as NumPy and Pandas are widely used for data manipulation and analysis.",
    5: "Information retrieval systems use algorithms to rank documents based on their relevance to the query.",
    6: "The Python programming language supports various libraries for machine learning, such as Scikit-learn and TensorFlow.",
    7: "Effective indexing techniques improve the performance of search engines by optimizing query processing.",
    8: "Python’s simplicity and readability make it a popular choice for beginners and professionals alike.",
    9: "Information retrieval systems often utilize data structures like inverted indexes to speed up search operations.",
    10: "Python's rich ecosystem includes libraries for web scraping, like BeautifulSoup and Scrapy, which are useful for gathering data for information retrieval."
  }

  # Add the documents to the index
  for doc_id,content in documents.items():
    index.add_document(doc_id,content)

  # Perform search queries
  print("Search results for 'information':", index.search("information"))
  print("Search results for 'indexing':", index.search("indexing"))
  print("Search results for 'documents':", index.search("documents"))
  print("Search results for 'threshold':", index.search("threshold"))
  print("Search results for 'python':", index.search("Python"))


  # Update document
  index.update_document(2, "Dynamic indexing can handle document updates seamlessly.")
  print("After update, search results for 'indexing':", index.search("indexing"))
# Out:
# Search results for 'information': [(1, 0), (1, 7), (1, 15), (3, 1), (5, 0), (9, 0), (10, 19)]
# Search results for 'indexing': [(3, 3), (7, 1)]
# Search results for 'documents': [(5, 7)]
# Search results for 'threshold': []
# Search results for 'python': [(2, 0), (4, 0), (6, 1)]
# After update, search results for 'indexing': [(3, 3), (7, 1), (2, 1)]

# %% [markdown]
# ### 2. Explaination for each Method in both the classes
#
# #### **Class `IndexSegment`:**
#
# - **`__init__(self):`**
#   Initializes an empty index using a `defaultdict` where each term points to a list of tuples, with each tuple containing the document ID and the position of the term in that document.
#
# - **`add_document(self, doc_id, content):`**
#   Adds a document to the index. It tokenizes the content into terms (by splitting on spaces) and adds each term, along with its position in the document, to the index.
#
# - **`merge(self, other):`**
#   Merges another `IndexSegment` into the current one by appending the posting lists of each term from `other` to the current index. This helps reduce the number of segments.
#
# #### **Class `DynamicIndex`:**
#
# - **`__init__(self, merge_threshold=2, buffer_size=5):`**
#   Initializes a dynamic index with a list of segments, a buffer segment, and a buffer size. The `merge_threshold` defines how many segments to merge at a time, and `buffer_size` defines how many documents can be stored in the buffer before it's flushed.
#
# - **`add_document(self, doc_id, content):`**
#   Adds a document to the buffer. If the buffer reaches its size limit (as defined by `buffer_size`), it flushes the buffer to create a new segment.
#
# - **`_flush_buffer(self):`**
#   Moves the buffer into the segments and resets the buffer. It also triggers merging of the segments if needed.
#
# - **`_merge_segments(self):`**
#   Merges segments in the list of segments. It checks if the number of segments is greater than or equal to the `merge_threshold` and merges them together to keep the number of segments manageable.
#
# - **`search(self, query):`**
#   Searches for a query term across all segments and the buffer. It returns a list of positions where the term is found.
#
# - **`update_document(self, doc_id, new_content):`**
#   Removes all references to a document (by its `doc_id`) from both the segments and the buffer. After that, it re-adds the document with its updated content.

# %% [markdown]
# ###  3. Explanation of `merge_threshold` and `buffer_size` in the Context of the Code
#
# #### **buffer_size:**
#
# - **Context in Code:**
#   In the `DynamicIndex` class, `buffer_size` defines the maximum number of documents that can be added to the in-memory buffer before the buffer is "flushed." When the buffer reaches the specified size, it is moved to the list of segments, and a new buffer is created for further document additions.
#
# - **Impact in the Code:**
#   - **Document Handling:** A larger `buffer_size` allows more documents to be accumulated in memory before flushing. This means that fewer flush operations will occur, leading to the creation of fewer segments. This can be advantageous if you want to minimize the number of segments but need to handle larger memory usage.
#   - **Memory Usage:** Larger buffers consume more memory as they hold more documents. This can be a trade-off between memory efficiency and the overhead of frequent buffer flushing.
#   - **Performance:** By reducing the number of flushes, you may reduce the overhead of segment creation and improve indexing performance. However, if the buffer size is too large, it might lead to increased memory consumption, which could affect the system's overall performance.
#
# #### **merge_threshold:**
#
# - **Context in Code:**
#   In the `DynamicIndex` class, `merge_threshold` specifies how many segments need to be present before a merge operation is triggered. When the number of segments meets or exceeds this threshold, the `merge_segments` method merges the segments to reduce the total number of segments in the index.
#
# - **Impact in the Code:**
#   - **Segment Management:** A lower `merge_threshold` results in more frequent merge operations. This means segments are merged together more often, which helps keep the number of segments smaller and more manageable. It ensures that the index does not grow indefinitely and remains efficient for searching.
#   - **Processing Overhead:** Frequent merging can increase the processing cost, as each merge operation involves combining segments and updating the index. This might affect the system's performance if merging is computationally intensive.
#   - **Search Efficiency:** By merging segments more frequently, you can improve search efficiency by reducing the number of segments that need to be searched. Fewer, larger segments can lead to faster search times compared to a larger number of smaller segments.

# %% [markdown]
# ### 4. execute the code on the 1000 documents dataset

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
dataset = "/content/drive/MyDrive/CSE 419/Lab Assign-4/1000_documents"

# %%
index = DynamicIndex(merge_threshold=2, buffer_size=5)

    # Read and index each .txt file
for filename in os.listdir(dataset):
    if filename.endswith('.txt'):
        doc_id = filename  # Use filename as a unique identifier
        file_path = os.path.join(dataset, filename)
        with open(file_path, 'r', encoding='utf-8') as file:
            content = file.read()
            index.add_document(doc_id, content)

# %%
index.search("thinking")
# Out:
# [('entertainment_67.txt', 361),
#  ('food_15.txt', 91),
#  ('food_70.txt', 349),
#  ('graphics_15.txt', 43),
#  ('graphics_40.txt', 336),
#  ('graphics_35.txt', 315),
#  ('graphics_52.txt', 1154),
#  ('graphics_52.txt', 1491),
#  ('historical_90.txt', 662),
#  ('historical_90.txt', 756),
#  ('medical_308.txt', 13),
#  ('medical_41.txt', 57),
#  ('politics_229.txt', 444),
#  ('sport_40.txt', 381),
#  ('sport_65.txt', 228),
#  ('sport_93.txt', 99),
#  ('sport_93.txt', 127),
#  ('technologie_56.txt', 123),
#  ('technologie_50.txt', 305),
#  ('technologie_78.txt', 508)]

# %%
while True:
  query = input("Enter your search query: ").strip()

  if query.lower() == 'n':
    print("Stopping the search.")
    break

  results = index.search(query)
  print(f"\nSearch results for query '{query}':")
  if results:
    for doc_id, position in results:
      print(f"Document ID: {doc_id}, Position: {position}")
  else:
    print("No results found.")
  print("\n")
# Out:
# Enter your search query: hello
#
# Search results for query 'hello':
# Document ID: graphics_10.txt, Position: 0
#
#
# Enter your search query: good
#
# Search results for query 'good':
# Document ID: business_11.txt, Position: 164
# Document ID: business_30.txt, Position: 291
# Document ID: business_30.txt, Position: 460
# Document ID: business_4.txt, Position: 136
# Document ID: business_27.txt, Position: 131
# Document ID: business_39.txt, Position: 196
# Document ID: business_37.txt, Position: 176
# Document ID: business_34.txt, Position: 124
# Document ID: business_21.txt, Position: 19
# Document ID: business_40.txt, Position: 64
# Document ID: business_50.txt, Position: 334
# Document ID: business_69.txt, Position: 335
# Document ID: business_53.txt, Position: 166
# Document ID: business_56.txt, Position: 168
# Document ID: business_78.txt, Position: 299
# Document ID: business_82.txt, Position: 166
# Document ID: business_81.txt, Position: 263
# Document ID: business_81.txt, Position: 418
# Document ID: entertainment_25.txt, Position: 232
# Document ID: entertainment_25.txt, Position: 250
# Document ID: entertainment_25.txt, Position: 292
# Document ID: entertainment_28.txt, Position: 72
# Document ID: entertainment_24.txt, Position: 134
# Document ID: entertainment_5.txt, Position: 132
# Document ID: entertainment_51.txt, Position: 272
# Document ID: entertainment_65.txt, Position: 250
# Document ID: entertainment_77.txt, Position: 257
# Document ID: food_11.txt, Position: 170
# Document ID: entertainment_88.txt, Position: 122
# Document ID: entertainment_85.txt, Position: 84
# Document ID: entertainment_85.txt, Position: 95
# Document ID: food_62.txt, Position: 35
# Document ID: food_64.txt, Position: 260
# Document ID: food_58.txt, Position: 216
# Document ID: food_60.txt, Position: 7
# Document ID: food_60.txt, Position: 83
# Document ID: food_51.txt, Position: 72
# Document ID: food_51.txt, Position: 92
# Document ID: food_90.txt, Position: 198
# Document ID: food_91.txt, Position: 23
# Document ID: food_85.txt, Position: 201
# Document ID: food_76.txt, Position: 26
# Document ID: food_78.txt, Position: 116
# Document ID: food_74.txt, Position: 128
# Document ID: food_94.txt, Position: 125
# Document ID: graphics_19.txt, Position: 7
# Document ID: graphics_19.txt, Position: 32
# Document ID: graphics_19.txt, Position: 86
# Document ID: graphics_32.txt, Position: 110
# Document ID: graphics_32.txt, Position: 167
# Document ID: graphics_44.txt, Position: 226
# Document ID: graphics_27.txt, Position: 182
# Document ID: graphics_28.txt, Position: 67
# Document ID: graphics_29.txt, Position: 87
# Document ID: graphics_42.txt, Position: 235
# Document ID: graphics_74.txt, Position: 1738
# Document ID: graphics_74.txt, Position: 2138
# Document ID: graphics_74.txt, Position: 3422
# Document ID: graphics_74.txt, Position: 6458
# Document ID: graphics_55.txt, Position: 37
# Document ID: graphics_66.txt, Position: 158
# Document ID: graphics_52.txt, Position: 870
# Document ID: graphics_52.txt, Position: 1204
# Document ID: graphics_52.txt, Position: 1246
# Document ID: graphics_90.txt, Position: 102
# Document ID: graphics_85.txt, Position: 488
# Document ID: historical_1.txt, Position: 366
# Document ID: historical_1.txt, Position: 392
# Document ID: historical_1.txt, Position: 436
# Document ID: graphics_82.txt, Position: 18
# Document ID: graphics_83.txt, Position: 40
# Document ID: graphics_83.txt, Position: 66
# Document ID: historical_2.txt, Position: 60
# Document ID: historical_2.txt, Position: 466
# Document ID: historical_15.txt, Position: 869
# Document ID: historical_4.txt, Position: 436
# Document ID: historical_4.txt, Position: 462
# Document ID: historical_4.txt, Position: 506
# Document ID: historical_4.txt, Position: 704
# Document ID: historical_81.txt, Position: 932
# Document ID: historical_96.txt, Position: 136
# Document ID: medical_152.txt, Position: 161
# Document ID: historical_85.txt, Position: 318
# Document ID: medical_289.txt, Position: 22
# Document ID: medical_335.txt, Position: 69
# Document ID: medical_244.txt, Position: 71
# Document ID: medical_188.txt, Position: 47
# Document ID: medical_278.txt, Position: 73
# Document ID: medical_285.txt, Position: 95
# Document ID: medical_308.txt, Position: 18
# Document ID: medical_499.txt, Position: 194
# Document ID: medical_364.txt, Position: 115
# Document ID: medical_425.txt, Position: 159
# Document ID: medical_40.txt, Position: 123
# Document ID: medical_542.txt, Position: 186
# Document ID: medical_564.txt, Position: 209
# Document ID: medical_67.txt, Position: 118
# Document ID: medical_560.txt, Position: 200
# Document ID: medical_642.txt, Position: 99
# Document ID: medical_590.txt, Position: 45
# Document ID: medical_586.txt, Position: 499
# Document ID: medical_694.txt, Position: 376
# Document ID: medical_694.txt, Position: 483
# Document ID: medical_694.txt, Position: 988
# Document ID: medical_694.txt, Position: 1048
# Document ID: politics_138.txt, Position: 371
# Document ID: politics_101.txt, Position: 348
# Document ID: politics_112.txt, Position: 237
# Document ID: politics_112.txt, Position: 252
# Document ID: politics_112.txt, Position: 268
# Document ID: politics_112.txt, Position: 329
# Document ID: medical_692.txt, Position: 90
# Document ID: medical_692.txt, Position: 112
# Document ID: politics_111.txt, Position: 711
# Document ID: politics_111.txt, Position: 718
# Document ID: politics_201.txt, Position: 97
# Document ID: politics_20.txt, Position: 370
# Document ID: politics_19.txt, Position: 487
# Document ID: politics_220.txt, Position: 321
# Document ID: politics_293.txt, Position: 465
# Document ID: politics_293.txt, Position: 588
# Document ID: politics_293.txt, Position: 1327
# Document ID: politics_293.txt, Position: 1543
# Document ID: politics_293.txt, Position: 1739
# Document ID: politics_293.txt, Position: 1752
# Document ID: politics_293.txt, Position: 2176
# Document ID: politics_293.txt, Position: 2183
# Document ID: space_11.txt, Position: 409
# Document ID: space_11.txt, Position: 801
# Document ID: politics_357.txt, Position: 68
# Document ID: politics_357.txt, Position: 162
# Document ID: space_20.txt, Position: 148
# Document ID: space_19.txt, Position: 72
# Document ID: space_19.txt, Position: 1125
# Document ID: space_18.txt, Position: 37
# Document ID: space_32.txt, Position: 196
# Document ID: space_29.txt, Position: 109
# Document ID: space_30.txt, Position: 217
# Document ID: space_30.txt, Position: 429
# Document ID: space_27.txt, Position: 400
# Document ID: space_27.txt, Position: 429
# Document ID: space_40.txt, Position: 1323
# Document ID: space_40.txt, Position: 1441
# Document ID: space_40.txt, Position: 1703
# Document ID: space_40.txt, Position: 1717
# Document ID: space_6.txt, Position: 1131
# Document ID: space_6.txt, Position: 1441
# Document ID: space_6.txt, Position: 2583
# Document ID: space_6.txt, Position: 2595
# Document ID: space_6.txt, Position: 2602
# Document ID: space_6.txt, Position: 2934
# Document ID: space_54.txt, Position: 3437
# Document ID: space_54.txt, Position: 3458
# Document ID: space_54.txt, Position: 3737
# Document ID: space_54.txt, Position: 3973
# Document ID: space_58.txt, Position: 630
# Document ID: space_49.txt, Position: 74
# Document ID: space_63.txt, Position: 64
# Document ID: space_52.txt, Position: 231
# Document ID: space_52.txt, Position: 235
# Document ID: space_86.txt, Position: 226
# Document ID: space_89.txt, Position: 91
# Document ID: space_87.txt, Position: 771
# Document ID: space_73.txt, Position: 27
# Document ID: space_73.txt, Position: 134
# Document ID: space_73.txt, Position: 218
# Document ID: space_79.txt, Position: 386
# Document ID: space_79.txt, Position: 408
# Document ID: space_79.txt, Position: 418
# Document ID: sport_14.txt, Position: 350
# Document ID: sport_14.txt, Position: 425
# Document ID: sport_10.txt, Position: 129
# Document ID: sport_34.txt, Position: 131
# Document ID: sport_34.txt, Position: 749
# Document ID: sport_42.txt, Position: 72
# Document ID: sport_42.txt, Position: 84
# Document ID: sport_44.txt, Position: 188
# Document ID: sport_46.txt, Position: 164
# Document ID: sport_68.txt, Position: 192
# Document ID: sport_68.txt, Position: 198
# Document ID: sport_63.txt, Position: 74
# Document ID: sport_69.txt, Position: 109
# Document ID: sport_69.txt, Position: 117
# Document ID: sport_64.txt, Position: 45
# Document ID: sport_59.txt, Position: 31
# Document ID: sport_59.txt, Position: 289
# Document ID: sport_59.txt, Position: 413
# Document ID: sport_58.txt, Position: 264
# Document ID: sport_58.txt, Position: 831
# Document ID: sport_56.txt, Position: 73
# Document ID: sport_72.txt, Position: 436
# Document ID: sport_70.txt, Position: 158
# Document ID: sport_70.txt, Position: 171
# Document ID: sport_61.txt, Position: 160
# Document ID: sport_61.txt, Position: 498
# Document ID: sport_71.txt, Position: 184
# Document ID: sport_78.txt, Position: 126
# Document ID: sport_92.txt, Position: 129
# Document ID: sport_9.txt, Position: 305
# Document ID: sport_98.txt, Position: 85
# Document ID: technologie_100.txt, Position: 488
# Document ID: technologie_17.txt, Position: 13
# Document ID: technologie_31.txt, Position: 275
# Document ID: technologie_23.txt, Position: 311
# Document ID: technologie_59.txt, Position: 502
# Document ID: technologie_5.txt, Position: 598
# Document ID: technologie_40.txt, Position: 191
# Document ID: technologie_72.txt, Position: 255
# Document ID: technologie_72.txt, Position: 257
# Document ID: technologie_74.txt, Position: 264
# Document ID: technologie_78.txt, Position: 182
# Document ID: technologie_64.txt, Position: 59
# Document ID: technologie_83.txt, Position: 225
# Document ID: technologie_68.txt, Position: 82
# Document ID: technologie_94.txt, Position: 349
# Document ID: technologie_93.txt, Position: 60
# Document ID: technologie_93.txt, Position: 117
# Document ID: technologie_93.txt, Position: 147
# Document ID: technologie_9.txt, Position: 997
# Document ID: technologie_9.txt, Position: 1006
# Document ID: technologie_95.txt, Position: 294
# Document ID: technologie_95.txt, Position: 307
#
#
# Enter your search query: python
#
# Search results for query 'python':
# No results found.
#
#
# Enter your search query: Python
#
# Search results for query 'Python':
# No results found.
#
#
# Enter your search query: test
#
# Search results for query 'test':
# Document ID: business_11.txt, Position: 532
# Document ID: business_11.txt, Position: 547
# Document ID: business_62.txt, Position: 109
# Document ID: entertainment_35.txt, Position: 171
# Document ID: food_63.txt, Position: 77
# Document ID: food_86.txt, Position: 181
# Document ID: food_85.txt, Position: 55
# Document ID: food_71.txt, Position: 151
# Document ID: graphics_98.txt, Position: 177
# Document ID: graphics_98.txt, Position: 252
# Document ID: historical_62.txt, Position: 695
# Document ID: historical_95.txt, Position: 1487
# Document ID: medical_329.txt, Position: 148
# Document ID: medical_329.txt, Position: 160
# Document ID: medical_329.txt, Position: 177
# Document ID: medical_329.txt, Position: 194
# Document ID: medical_329.txt, Position: 211
# Document ID: medical_329.txt, Position: 304
# Document ID: medical_188.txt, Position: 39
# Document ID: medical_485.txt, Position: 1062
# Document ID: medical_485.txt, Position: 2227
# Document ID: medical_485.txt, Position: 2606
# Document ID: medical_485.txt, Position: 3406
# Document ID: medical_488.txt, Position: 2603
# Document ID: medical_488.txt, Position: 2622
# Document ID: medical_488.txt, Position: 2633
# Document ID: medical_488.txt, Position: 2654
# Document ID: medical_488.txt, Position: 2755
# Document ID: medical_488.txt, Position: 2832
# Document ID: medical_487.txt, Position: 3088
# Document ID: politics_134.txt, Position: 32
# Document ID: politics_137.txt, Position: 6
# Document ID: politics_173.txt, Position: 259
# Document ID: politics_182.txt, Position: 4
# Document ID: politics_182.txt, Position: 27
# Document ID: politics_210.txt, Position: 218
# Document ID: politics_229.txt, Position: 3
# Document ID: politics_220.txt, Position: 17
# Document ID: politics_34.txt, Position: 239
# Document ID: space_100.txt, Position: 127
# Document ID: space_11.txt, Position: 756
# Document ID: space_11.txt, Position: 1112
# Document ID: space_14.txt, Position: 704
# Document ID: space_14.txt, Position: 829
# Document ID: space_14.txt, Position: 2230
# Document ID: space_31.txt, Position: 79
# Document ID: space_54.txt, Position: 985
# Document ID: space_54.txt, Position: 2269
# Document ID: space_58.txt, Position: 378
# Document ID: space_58.txt, Position: 471
# Document ID: space_58.txt, Position: 676
# Document ID: space_44.txt, Position: 125
# Document ID: space_52.txt, Position: 1142
# Document ID: space_88.txt, Position: 220
# Document ID: space_88.txt, Position: 402
# Document ID: space_77.txt, Position: 119
# Document ID: sport_17.txt, Position: 179
# Document ID: space_95.txt, Position: 112
# Document ID: sport_40.txt, Position: 10
# Document ID: sport_35.txt, Position: 46
# Document ID: sport_35.txt, Position: 280
# Document ID: sport_44.txt, Position: 114
# Document ID: sport_26.txt, Position: 61
# Document ID: sport_38.txt, Position: 20
# Document ID: sport_47.txt, Position: 22
# Document ID: sport_47.txt, Position: 77
# Document ID: sport_45.txt, Position: 298
# Document ID: sport_49.txt, Position: 131
# Document ID: sport_51.txt, Position: 73
# Document ID: sport_51.txt, Position: 97
# Document ID: sport_51.txt, Position: 249
# Document ID: sport_66.txt, Position: 531
# Document ID: sport_50.txt, Position: 138
# Document ID: sport_50.txt, Position: 253
# Document ID: sport_88.txt, Position: 132
# Document ID: sport_82.txt, Position: 123
# Document ID: sport_82.txt, Position: 191
# Document ID: sport_82.txt, Position: 284
# Document ID: sport_89.txt, Position: 23
# Document ID: sport_89.txt, Position: 37
# Document ID: sport_89.txt, Position: 212
# Document ID: sport_91.txt, Position: 272
# Document ID: sport_79.txt, Position: 162
# Document ID: sport_79.txt, Position: 189
# Document ID: sport_80.txt, Position: 88
# Document ID: sport_81.txt, Position: 277
# Document ID: sport_81.txt, Position: 331
# Document ID: technologie_22.txt, Position: 263
# Document ID: technologie_20.txt, Position: 60
# Document ID: technologie_14.txt, Position: 278
# Document ID: technologie_53.txt, Position: 29
# Document ID: technologie_53.txt, Position: 372
# Document ID: technologie_6.txt, Position: 574
# Document ID: technologie_9.txt, Position: 979
#
#
# Enter your search query: n
# Stopping the search.
